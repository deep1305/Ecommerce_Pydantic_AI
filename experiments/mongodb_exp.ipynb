# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://smartdeep1298_db_user:fsx4JBPBWwXHmB53@ecomm-pydantic.xk2xcle.mongodb.net/?appName=ecomm-pydantic")

# %%
db = client["ecom_db"]

collection = db["products"]

print("connectted to mongo db")
# Out:
# connectted to mongo db

# %%
order = {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
}

collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('6a13c390eb94331fd412050f'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6a13c498eb94331fd4120510'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('6a13c498eb94331fd4120511'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('6a13c498eb94331fd4120512'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# TEXT 2 Nosql

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('6a13c498eb94331fd4120511'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "men"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('6a13c498eb94331fd4120510'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}

# %% [markdown]
# UPDATE

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %%
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6a13c498eb94331fd4120510'), 'name': 'Jeans', 'price': 1399, 'category': 'men'}
# {'_id': ObjectId('6a13c498eb94331fd4120511'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('6a13c498eb94331fd4120512'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# DELETE

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")
# Out:
# Product Deleted ✅

# %%
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6a13c498eb94331fd4120510'), 'name': 'Jeans', 'price': 1399, 'category': 'men'}
# {'_id': ObjectId('6a13c498eb94331fd4120511'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
collection.delete_many({})

print("All Products Deleted ✅")
# Out:
# All Products Deleted ✅

# %%
all_products = collection.find()

for p in all_products:
    print(p)

# %%
collection.drop()

print("Collection Dropped ✅")
# Out:
# Collection Dropped ✅

# %%
# View All Products
products_collection = db["products"]
print("=== PRODUCTS ===")
for p in products_collection.find():
    print(p)

# View All Orders
orders_collection = db["orders"]
print("\n=== ORDERS ===")
for o in orders_collection.find():
    print(o)
